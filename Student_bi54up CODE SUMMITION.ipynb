# %% [markdown]
# # CETM50 -  Technology Management For Organisations
# ## Name: AKINWUMI ISAAC KAYODE
#
# ## Student ID: bi54up

# %%
import csv
import json
import xml.etree.ElementTree as ET

# %% [markdown]
# ## Function to parse CSV data, merge JSON data, merge XML data, read text file

# %%
def parse_csv_data(file_path):
    """
    Parses CSV data and returns a dictionary.

    :param file_path: Path to the CSV file.
    :return: Dictionary containing parsed CSV data.
    """
    parsed_data = {}
    with open(file_path, newline='') as csvfile:
        csv_reader = csv.DictReader(csvfile)
        for row in csv_reader:
            full_name = row['First Name'] + ' ' + row['Second Name']
            parsed_data[full_name] = row
    return parsed_data

# %%
def merge_json_data(file_path, csv_data):
    """
    Merges JSON data with existing CSV data.

    :param file_path: Path to the JSON file.
    :param csv_data: Existing CSV data dictionary.
    """
    with open(file_path) as jsonfile:
        json_data = json.load(jsonfile)
        for record in json_data:
            full_name = record['firstName'] + ' ' + record['lastName']
            # Handle 'debt' field
            if 'debt' in record and isinstance(record['debt'], dict):
                debt_info = record['debt']
                dept_amount = debt_info.get('amount', 0)
                dept_time_period_years = debt_info.get('time_period_years', 0)
                del record['debt']
            else:
                dept_amount = 0
                dept_time_period_years = 0
            record['dept_amount'] = dept_amount
            record['dept_time_period_years'] = dept_time_period_years
            csv_data.setdefault(full_name, {}).update(record)

# %%
def merge_xml_data(file_path, csv_data):
    """
    Merges XML data with existing CSV data.

    :param file_path: Path to the XML file.
    :param csv_data: Existing CSV data dictionary.
    """
    xml_data = ET.parse(file_path).getroot()
    for user in xml_data.findall('user'):
        full_name = f"{user.attrib['firstName']} {user.attrib['lastName']}"
        record = {attr: user.attrib[attr] for attr in user.attrib}
        csv_data.setdefault(full_name, {}).update(record)

# %%
def read_text_file(file_path):
    """
    Reads a text file line by line and returns the data in a list.

    :param file_path: Path to the text file.
    :return: List containing each line of the text file.
    """
    data = []
    with open(file_path, mode='r', encoding='utf-8') as file:
        data = file.readlines()
    return data

# %%
# Read text file
txt_data = read_text_file('cetm50_23_4_data/user_data_23_4.txt')
for i in range(0, 4):
    print(txt_data[i])

# Parse CSV data
csv_data = parse_csv_data('cetm50_23_4_data/user_data_23_4.csv')

# Merge JSON data
merge_json_data('cetm50_23_4_data/user_data_23_4.json', csv_data)

# Merge XML data
merge_xml_data('cetm50_23_4_data/user_data_23_4.xml', csv_data)
# Out:
# "Valerie Ellis e-mailed in overnight (Full details in Ticket #1839). During account creation something went wrong and their security code is wrong on their billing information. Bank is rejecting any payment until it's corrected. They're not sure what happened, but said to try "762". Can you please action this and try re-bill the client? Let me know if there's any further issues with it. Thanks"
#
# "Congratulations on the promotion West! We wouldn't have survived through the pandemic without you and your team. As a token of our appreciation, we've given you a £2100 salary bump. This will take effect as of next month's payroll. At Williams-Wheeler we value the care and work you put in. See you on Monday Charlie, enjoy!"
#
# "Happy Birthday Mr Charlie Short! You're 52 today. Our latest offers will be sure to get you into the party spirit!"
#
# "Hannah, the pension policy has changed slightly since the meeting last week. I know you've just finished putting through all the changes, but I need you to look at Mr Martin's file. We'll need to  modify it by adding another 0.15% on top of the existing £22896. Drop me a message when you've done this please, it's quite urgent."

# %%
# Convert merged dictionary into a unified dataset format
unified_data = list(csv_data.values())

# Define updates based on conditions
updates = {
    ('Valerie', 'Ellis'): {'credit_card_security_code': 762},
    ('Charlie', 'West'): {'salary': 2100, 'age': 52},
    ('Martin', None): {'pension': lambda x: 0.0015 * int(x) + int(x)}  # lambda function for dynamic update
}

# Apply updates
for record in unified_data:
    for (first_name, last_name), update_fields in updates.items():
        if record.get('firstName') == first_name and record.get('lastName') == last_name:
            for field, value in update_fields.items():
                if callable(value):
                    record[field] = value(record.get(field, 0))
                else:
                    record[field] = value
            print(f"{', '.join(update_fields.keys())} Updated")

# Drop specified columns from each record
columns_to_drop = ['First Name', 'Second Name', 'Age (Years)', 'Sex', 'Vehicle Make', 'Vehicle Model', 'Vehicle Year', 'Vehicle Type', 'debt']
for record in unified_data:
    record['Vehicle_Make'] = record['Vehicle Make']
    record['Vehicle_Model'] = record['Vehicle Model']
    record['Vehicle_Year'] = record['Vehicle Year']
    record['Vehicle_Type'] = record['Vehicle Type']
    for column in columns_to_drop:
        record.pop(column, None)

# Write unified data to JSON
with open('customer_unified_data.json', 'w') as jsonfile:
    json.dump(unified_data, jsonfile, indent=4)
# Out:
# salary, age Updated
# credit_card_security_code Updated

# %%
#unified_data

# %%
# ! pip install pony pymysql

# %%
from pony.orm import *

# Database configuration
host = 'europa.ashley.work'
user_and_database = 'student_bi54up'
password = 'iE93F2@8EhM@1zhD&u9M@K'

# Set up Pony ORM database
db = Database()

# Bind the database with MySQL
db.bind(provider='mysql', host=host,
        user=user_and_database,
        passwd=password,
        database=user_and_database)

# Enable SQL debug mode
sql_debug(True)

# db.drop_table("customerentity", with_all_data=True, if_exists=True)
########################################################################
class CustomerEntity(db.Entity):
    """
    Pony ORM model of records table
    """
    id = PrimaryKey(int, auto=True)
    firstName = Required(str)
    lastName = Required(str)
    age = Required(int)
    sex = Required(str)
    address_main = Required(str)
    address_city = Required(str)
    Vehicle_Make = Required(str)
    Vehicle_Model = Required(str)
    Vehicle_Year = Required(int)
    Vehicle_Type = Required(str)
    retired = Optional(bool)
    credit_card_number = Required(str)
    credit_card_security_code = Required(int)
    credit_card_start_date = Required(str)
    credit_card_end_date = Required(str)
    dept_amount = Optional(float)
    dept_time_period_years = Optional(float)
    dependants = Optional(str)
    marital_status = Required(str)
    salary = Required(int)
    pension = Optional(float)
    company = Optional(str)
    commute_distance = Optional(float)
    address_postcode = Optional(str)
    iban = Optional(str)

db.generate_mapping(create_tables=True) 
sql_debug(True)


def push_data(db_class, data):
  """
    Uploads data to the specified database table.

    :param db_class: Pony ORM entity class representing the database table.
    :param data: List of dictionaries representing the data to be uploaded.
  """
  try:
    for entry in data:
        db_class(**entry)
    commit()
    print('Entries Added Successfully')
  except Exception as e:
        print(f"An error occurred while uploading data to the database: {e}")
# Out:
# GET NEW CONNECTION
# RELEASE CONNECTION
# GET CONNECTION FROM THE LOCAL POOL
# SET foreign_key_checks = 0
# CREATE TABLE `customerentity` (
#   `id` INTEGER PRIMARY KEY AUTO_INCREMENT,
#   `firstname` VARCHAR(255) NOT NULL,
#   `lastname` VARCHAR(255) NOT NULL,
#   `age` INTEGER NOT NULL,
#   `sex` VARCHAR(255) NOT NULL,
#   `address_main` VARCHAR(255) NOT NULL,
#   `address_city` VARCHAR(255) NOT NULL,
#   `vehicle_make` VARCHAR(255) NOT NULL,
#   `vehicle_model` VARCHAR(255) NOT NULL,
#   `vehicle_year` INTEGER NOT NULL,
#   `vehicle_type` VARCHAR(255) NOT NULL,
#   `retired` BOOLEAN,
#   `credit_card_number` VARCHAR(255) NOT NULL,
#   `credit_card_security_code` INTEGER NOT NULL,
#   `credit_card_start_date` VARCHAR(255) NOT NULL,
#   `credit_card_end_date` VARCHAR(255) NOT NULL,
#   `dept_amount` DOUBLE,
#   `dept_time_period_years` DOUBLE,
#   `dependants` VARCHAR(255) NOT NULL,
#   `marital_status` VARCHAR(255) NOT NULL,
#   `salary` INTEGER NOT NULL,
#   `pension` DOUBLE,
#   `company` VARCHAR(255) NOT NULL,
#   `commute_distance` DOUBLE,
#   `address_postcode` VARCHAR(255) NOT NULL,
#   `iban` VARCHAR(255) NOT NULL
# )
#
# SELECT `customerentity`.`id`, `customerentity`.`firstname`, `customerentity`.`lastname`, `customerentity`.`age`, `customerentity`.`sex`, `customerentity`.`address_main`, `customerentity`.`address_city`, `customerentity`.`vehicle_make`, `customerentity`.`vehicle_model`, `customerentity`.`vehicle_year`, `customerentity`.`vehicle_type`, `customerentity`.`retired`, `customerentity`.`credit_card_number`, `customerentity`.`credit_card_security_code`, `customerentity`.`credit_card_start_date`, `customerentity`.`credit_card_end_date`, `customerentity`.`dept_amount`, `customerentity`.`dept_time_period_years`, `customerentity`.`dependants`, `customerentity`.`marital_status`, `customerentity`.`salary`, `customerentity`.`pension`, `customerentity`.`company`, `customerentity`.`commute_distance`, `customerentity`.`address_postcode`, `customerentity`.`iban`
# FROM `customerentity` `customerentity`
# WHERE 0 = 1
#
# COMMIT
# SET foreign_key_checks = 1
# CLOSE CONNECTION

# %%
push_data(CustomerEntity, unified_data)
# Out:
# GET NEW CONNECTION
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Leon', 'Smith', 48, 'Male', '0 Shaw plains', "O'Neillshire", 'Mercedes-Benz', 'Astro Cargo', 2009, 'Pickup', True, '2292406027303835', 750, '09/18', '01/22', 0.0, 0.0, '2', 'married or civil partner', 65911, 0.0, 'Gilbert, Williams and Quinn', 15.68, 'DY0 3SG', 'GB05DRJP98363742599825']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Margaret', 'Mason', 35, 'Female', 'Studio 8 Craig stravenue', 'West Stephanie', 'Honda', 'Sable', 2015, 'Van/Minivan', True, '30231894919500', 460, '05/23', '01/27', 0.0, 0.0, '1', 'married or civil partner', 19095, 0.0, 'Gibson PLC', 6.13, 'WR2H 3NN', 'GB60KAOM78304632971837']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Guy', 'Harrison', 26, 'Male', '694 Allan underpass', 'West Lucyshire', 'Chevrolet', 'S60', 2013, 'SUV', True, '4470811972956349', 201, '10/17', '06/25', 0.0, 0.0, '4', 'single', 22704, 0.0, 'Collins, Wade and Parker', 7.14, 'WR4M 2LP', 'GB95ASFR17716818519894']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Denise', 'Robinson', 30, 'Female', 'Studio 3 Zoe plain', 'Lake Leighside', 'Ford', 'Tucson', 2002, 'Sedan', True, '6538381451448304', 787, '06/21', '02/23', 0.0, 0.0, '2', 'single', 93818, 0.0, 'Higgins-Wallis', 19.68, 'E17 1TN', 'GB04BDET54533760891177']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Simon', 'Fox', 27, 'Male', '3 Farrell landing', 'East Nathanhaven', 'Toyota', 'Dart', 2005, 'SUV', True, '345302782495497', 320, '03/17', '04/32', 0.0, 0.0, '', 'married or civil partner', 46300, 0.0, 'Carey-Owens', 12.34, 'CT99 0XU', 'GB03NSDY21514645285507']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Tom', 'Cooke', 69, 'Male', 'Flat 85 Francesca club', 'Donaldton', 'Hyundai', 'Liberty', 2019, 'Pickup', True, '4508482106453342', 995, '12/19', '10/22', 0.0, 0.0, '2', 'single', 78099, 0.0, 'Parker PLC', 17.52, 'G28 1EQ', 'GB76CPZH28462200647918']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Fiona', 'Marshall', 86, 'Female', 'Flat 03k Zoe mountains', 'Mosstown', 'Chevrolet', 'Pathfinder', 2006, 'SUV', True, '4424742584764', 296, '01/19', '05/29', 0.0, 0.0, '2', 'married or civil partner', 27329, 29558.0, 'N/A', 0.0, 'B3 9ZN', 'GB49BDWW43070364283733']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Mitchell', 'Davidson', 84, 'Male', "667 O'Brien land", 'Jonesbury', 'Subaru', 'A8', 2006, 'Sedan, Hatchback, Wagon', True, '676251959745', 376, '10/22', '04/29', 0.0, 0.0, '1', 'married or civil partner', 72088, 28111.0, 'N/A', 0.0, 'NP3 5ZP', 'GB24SZKG28634206052106']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Sam', 'Long', 83, 'Male', '4 Vincent drive', 'Stewartton', 'Mercedes-Benz', 'Azure T', 2018, 'Coupe', True, '2245031471396677', 6, '05/19', '02/26', 0.0, 0.0, '2', 'single', 58511, 26792.0, 'N/A', 0.0, 'NP5 2SJ', 'GB16OLBW26880983186148']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Sean', 'Perry', 87, 'Male', '54 Victor walks', 'Lake Roy', 'Ford', '1500 Regular Cab', 2010, 'SUV', True, '3571761306387507', 5454, '01/23', '02/25', 0.0, 0.0, '2', 'married or civil partner', 72515, 32420.0, 'N/A', 0.0, 'EX27 3XW', 'GB24TVGV89818186516727']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Jacob', 'Bennett', 66, 'Male', '0 Barnes club', 'New Jennachester', 'Mercedes-Benz', 'Impreza', 1999, 'SUV', True, '4993777051811200', 244, '03/19', '04/20', 0.0, 0.0, '1', 'single', 92862, 0.0, 'Smith, Osborne and Hammond', 19.55, 'DN5R 9DX', 'GB37OBOT69175746358471']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Lydia', 'Henderson', 62, 'Female', 'Flat 4 Dominic courts', 'Port Joshview', 'Nissan', 'GLC Coupe', 2006, 'SUV', True, '3512212241942610', 492, '12/18', '03/23', 0.0, 0.0, '1', 'divorced', 90083, 0.0, 'Akhtar, Jones and Morris', 19.18, 'B55 5BB', 'GB49YWRF00584915087635']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Nathan', 'Slater', 81, 'Male', 'Flat 71U Elizabeth mission', 'Ritafurt', 'Cadillac', 'RLX', 1992, 'Sedan', True, '3577861995095736', 939, '10/20', '06/29', 0.0, 0.0, '2', 'divorced', 56794, 28402.0, 'N/A', 0.0, 'S74 4AJ', 'GB07LTNZ30627642850580']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Claire', 'Russell', 41, 'Female', 'Studio 1 Williams springs', 'Port Jack', 'Mercedes-Benz', 'Voyager', 1992, 'Van/Minivan', True, '2288206984756595', 918, '02/19', '11/31', 0.0, 0.0, '2', 'married or civil partner', 51199, 0.0, 'Yates Inc', 13.23, 'M54 6EA', 'GB84JZQA63843285464433']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Katy', 'Green', 78, 'Female', '939 Gould well', 'South Scott', 'Volvo', 'Galant', 1992, 'Wagon', True, '213187531453197', 8990, '12/14', '12/33', 0.0, 0.0, '2', 'married or civil partner', 47424, 0.0, 'James, Richardson and Cooke', 12.54, 'S3 6HS', 'GB83MMRZ64018472597921']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Duncan', 'Moore', 67, 'Male', '5 Lydia parks', 'Lesleymouth', 'Volkswagen', 'SLK-Class', 1997, 'Sedan', True, '2705462381301924', 274, '06/16', '11/29', 0.0, 0.0, '2', 'married or civil partner', 67814, 0.0, 'Griffiths Group', 15.98, 'E87 9TP', 'GB35IJYJ72719118013461']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Abbie', 'Miller', 73, 'Female', 'Studio 61 Kayleigh drive', 'Lake Victoriaville', 'Dodge', 'del Sol', 2002, 'Sedan', True, '503870401257', 653, '07/15', '08/27', 0.0, 0.0, '2', 'single', 38800, 0.0, 'Lewis-Gibbons', 10.87, 'LS0M 9LG', 'GB20NEGF61781527471339']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Amber', 'Hobbs', 21, 'Female', 'Flat 14n Emily passage', 'Clareland', 'Toyota', 'Rodeo', 1999, 'Van/Minivan', True, '4108286226488071625', 254, '12/17', '11/26', 0.0, 0.0, '2', 'married or civil partner', 26372, 0.0, 'Andrews, Collins and Fraser', 8.08, 'SS66 4AX', 'GB56QXRS20758368749724']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Samuel', 'Daniels', 47, 'Male', 'Flat 1 Taylor ramp', 'Lake Eileen', 'Volvo', 'Clarity Electric', 2016, 'SUV', True, '676170955675', 210, '07/18', '04/24', 0.0, 0.0, '2', 'married or civil partner', 56218, 0.0, 'Hughes Group', 14.1, 'FK92 5YA', 'GB69EDMQ96008466449188']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Louise', 'Parry', 66, 'Female', 'Flat 7 Amelia plaza', 'New Michellebury', 'Ford', 'Ram 1500 Quad Cab', 2003, 'Sedan, Coupe', True, '568711564332', 160, '11/19', '07/20', 0.0, 0.0, '1', 'married or civil partner', 53080, 0.0, 'Willis LLC', 13.56, 'N75 6YP', 'GB41NNRI52449172646036']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['June', 'Macdonald', 67, 'Female', 'Studio 92s Kim light', 'New Martyn', 'Cadillac', 'Camaro', 2016, 'Sedan, Hatchback', True, '346398133417692', 777, '05/15', '12/20', 0.0, 0.0, '2', 'single', 90360, 0.0, 'Allen, Gill and Lewis', 19.22, 'E40 3ZS', 'GB80ZPSW88048103878430']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Eileen', 'Lee', 55, 'Female', 'Flat 3 Martin greens', 'New Georgina', 'Volkswagen', 'Grand Cherokee', 2015, 'Sedan', True, '3542537199382227', 639, '07/18', '04/33', 0.0, 0.0, '2', 'married or civil partner', 25370, 0.0, 'Gregory, Martin and Thompson', 7.83, 'W3 5NS', 'GB44CJCO44546702771777']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Sian', 'Mason', 72, 'Female', '981 Lindsey cove', 'North Maureen', 'Toyota', 'Armada', 1993, 'Hatchback, Convertible', True, '213197134449039', 945, '02/19', '06/20', 0.0, 0.0, '1', 'single', 94647, 0.0, 'Savage Group', 19.79, 'E35 9FB', 'GB76POLE49461500631985']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Brett', 'Mason', 89, 'Male', 'Studio 72 Harding throughway', 'West Melanieport', 'Mercedes-Benz', 'Neon', 2010, 'Sedan', True, '4463563861248374', 517, '01/15', '02/15', 0.0, 0.0, '2', 'single', 40299, 14849.0, 'N/A', 0.0, 'N51 3NY', 'GB67IITC61448014947824']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Joan', 'Clarke', 83, 'Female', 'Flat 84R Turner extensions', 'Keithview', 'Audi', 'Fusion', 2008, 'Van/Minivan', True, '213118805752212', 586, '04/21', '09/23', 0.0, 0.0, '3', 'married or civil partner', 27713, 24298.0, 'N/A', 0.0, 'BR5 4NN', 'GB86YOJQ80595094031570']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Lynne', 'Harris', 90, 'Female', 'Studio 5 Jennings center', 'Jamesfort', 'Chevrolet', 'California', 2011, 'Coupe, Convertible', True, '502073610037', 488, '09/21', '05/31', 0.0, 0.0, '1', 'married or civil partner', 55155, 33451.0, 'N/A', 0.0, 'HS0 5WJ', 'GB64ILZL41206899433806']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Tony', 'Singh', 77, 'Male', '2 Hazel canyon', 'Harrisbury', 'Ford', 'Ranger Super Cab', 1997, 'Pickup', True, '4295122257025054', 327, '08/18', '01/21', 0.0, 0.0, '3', 'single', 45179, 21708.0, 'N/A', 0.0, 'FK3A 5QE', 'GB40PLHF29287100735977']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Arthur', 'Austin', 61, 'Male', 'Studio 2 Khan summit', 'South Lesliestad', 'Dodge', 'Montana', 2018, 'Van/Minivan', True, '3578878361352722', 33, '12/14', '12/26', 0.0, 0.0, '1', 'married or civil partner', 88788, 0.0, 'Dobson, French and Lane', 19.01, 'G3F 2UD', 'GB63GYRO25308722630716']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Damien', 'Turner', 67, 'Male', 'Studio 32 Martin drive', 'West Sophiechester', 'Ford', 'TITAN XD Crew Cab', 2005, 'Pickup', True, '4305354938592644', 510, '02/22', '09/26', 0.0, 0.0, '4', 'married or civil partner', 94948, 0.0, 'Carr PLC', 19.83, 'BS7Y 6YX', 'GB79DVKS10035105100756']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Elaine', 'Andrews', 57, 'Female', 'Studio 91P Williams drives', 'West Hayleystad', 'Chrysler', 'NX', 1999, 'Coupe, Convertible', True, '4576190619337981742', 485, '06/18', '10/23', 0.0, 0.0, '2', 'married or civil partner', 48475, 0.0, 'Foster, Hewitt and Green', 12.74, 'IV3N 8PA', 'GB80VCHH31156430087654']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Dominic', 'Hayes', 48, 'Male', 'Flat 63a Declan shoal', 'Lake Connor', 'FIAT', 'XC90', 2000, 'Hatchback, Convertible', True, '4028001887313706380', 273, '12/20', '09/28', 0.0, 0.0, '2', 'single', 81863, 0.0, 'Perry-Perry', 18.05, 'RH13 7ZB', 'GB07DEES40439892276875']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Sally', 'Holt', 57, 'Female', '1 Edward curve', 'Ashleighchester', 'Saab', 'Equus', 2019, 'SUV', True, '2255853101350601', 249, '07/18', '05/30', 0.0, 0.0, '4', 'divorced', 26572, 0.0, 'Sullivan-Bennett', 8.13, 'BB2V 3HF', 'GB65CJMP86885804433761']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Lindsey', 'Davies', 85, 'Female', '6 Smart mews', 'Lawrenceland', 'Toyota', 'Corsica', 1999, 'Sedan', True, '213181577942825', 897, '08/18', '12/27', 0.0, 0.0, '2', 'divorced', 36249, 10897.0, 'N/A', 0.0, 'HP2H 7XT', 'GB30IAYG49858526126504']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Rhys', 'George', 48, 'Male', 'Studio 7 Hyde rapids', 'Kimberg', 'Lexus', 'Ram 2500 Mega Cab', 2018, 'Hatchback', True, '4935476896140', 199, '12/16', '07/34', 0.0, 0.0, '2', 'married or civil partner', 69733, 0.0, 'Lewis-Spencer', 16.28, 'N13 4RA', 'GB71TUIT34944299800233']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Leonard', 'Lewis', 44, 'Male', 'Studio 2 Lydia viaduct', 'Kieranburgh', 'Dodge', 'Odyssey', 1998, 'Sedan', True, '213159827272987', 109, '03/18', '03/23', 0.0, 0.0, '1', 'single', 70789, 0.0, 'Butler PLC', 16.44, 'DD2E 1QL', 'GB97IAOX65027063991509']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Sarah', 'Parsons', 19, 'Female', '02 Gillian parks', 'New Laurenborough', 'Toyota', 'Acadia', 2018, 'Wagon', True, '213147340155557', 353, '10/22', '04/24', 0.0, 0.0, '2', 'divorced', 73271, 0.0, 'Jenkins-Taylor', 16.81, 'NG2 5UT', 'GB08SUWM24202556232591']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Kim', 'Baxter', 89, 'Female', 'Studio 8 Williams streets', 'Willistown', 'Rolls-Royce', 'Forte', 2000, 'SUV', True, '3536596586958062', 6204, '11/21', '03/22', 0.0, 0.0, '2', 'married or civil partner', 22032, 23977.0, 'N/A', 0.0, 'B5 2RA', 'GB44UKQY96576506843301']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Danny', 'Evans', 32, 'Male', 'Studio 26 Clark springs', 'North Jadebury', 'Acura', 'Jetta', 2011, 'Van/Minivan', True, '4189767514391126', 117, '02/20', '05/26', 0.0, 0.0, '1', 'married or civil partner', 73132, 0.0, 'Sheppard Group', 16.79, 'EN7 0YF', 'GB50IIIL66406656981746']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Brett', 'Smith', 64, 'Male', 'Flat 5 Taylor motorway', 'Osborneville', 'Mercedes-Benz', 'Cayenne', 2004, 'SUV', True, '377291001890870', 579, '10/18', '07/22', 0.0, 0.0, '2', 'single', 82725, 0.0, 'Vaughan-Johnson', 18.17, 'AB28 3WW', 'GB73NMDC51604619074606']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Jane', 'Bradley', 46, 'Female', 'Studio 37 Christian stravenue', 'North Garryview', 'Ram', 'Veloster', 2019, 'Sedan', True, '588068113814', 389, '08/19', '11/19', 0.0, 0.0, '1', 'married or civil partner', 41041, 0.0, 'Taylor-French', 11.32, 'SW28 7XA', 'GB60BFAS05951148186081']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Paige', 'Smith', 60, 'Female', 'Flat 75N Hall well', 'Begumburgh', 'Kia', 'Express 2500 Cargo', 2009, 'Pickup', True, '6557219219890324', 3208, '01/22', '07/22', 0.0, 0.0, '3', 'divorced', 48920, 0.0, 'Owen-Shaw', 12.82, 'S01 8LE', 'GB79BELG16678705988455']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Kevin', 'Clarke', 72, 'Male', 'Studio 46C Ricky estate', 'Lake Duncan', 'McLaren', 'F150 Regular Cab', 2011, 'Pickup', True, '4724742275267817', 265, '08/23', '05/30', 0.0, 0.0, '3', 'married or civil partner', 20746, 0.0, 'White-Berry', 6.6, 'N6W 4XF', 'GB48XXPX70426035821218']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Ross', 'Parsons', 31, 'Male', 'Flat 9 Sian cove', 'Terenceton', 'Kia', 'Grand Vitara', 2008, 'Van/Minivan', True, '213144904226916', 408, '04/18', '01/26', 0.0, 0.0, '3', 'married or civil partner', 25084, 0.0, 'Williams Group', 7.76, 'TD86 0DT', 'GB08PNMM82105836350081']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Jay', 'Simpson', 75, 'Male', '26 Francis forge', 'Gavinmouth', 'Dodge', 'Safari Passenger', 2015, 'Hatchback', True, '4151827847394744', 699, '08/23', '11/30', 0.0, 0.0, '3', 'married or civil partner', 35718, 24551.0, 'N/A', 0.0, 'N2 9PE', 'GB46NFKB91123665150041']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Grace', 'Gray', 42, 'Female', '887 Edwards junction', 'Ritaton', 'GMC', 'GTI', 2012, 'Sedan', True, '2715533144715838', 426, '10/20', '10/31', 0.0, 0.0, '3', 'divorced', 53501, 0.0, 'Cross-Young', 13.64, 'LA5 9DS', 'GB98PSFQ71611294270461']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Clifford', 'Campbell', 63, 'Male', '9 Jackson shoal', 'New Christine', 'Oldsmobile', 'Challenger', 2010, 'Convertible, Coupe', True, '4304027812716122', 670, '04/22', '04/26', 0.0, 0.0, '2', 'married or civil partner', 61785, 0.0, 'Austin, Rose and Bowen', 15.03, 'S0 7LB', 'GB04IDAL93836415521547']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Roger', 'Griffiths', 67, 'Male', '269 Skinner valleys', 'North Ben', 'Nissan', 'Colorado Crew Cab', 2015, 'Hatchback', True, '501885281011', 244, '02/20', '12/22', 0.0, 0.0, '3', 'married or civil partner', 39693, 0.0, 'Phillips Inc', 11.05, 'E7 1DJ', 'GB93OCXS08337664074840']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Mathew', 'Coates', 50, 'Male', 'Studio 18 Smith forges', 'Bellville', 'Dodge', 'C-Class', 2005, 'Sedan', True, '3582577319082340', 136, '09/16', '12/28', 0.0, 0.0, '1', 'married or civil partner', 69217, 0.0, 'Lee Inc', 16.2, 'WR7 7XG', 'GB17EMTG82275537508867']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Grace', 'Brown', 20, 'Female', '27 Hussain squares', 'Emilyburgh', 'Toyota', 'X-Type', 2018, 'Sedan, Wagon', True, '3511605504164288', 450, '02/22', '11/27', 0.0, 0.0, '3', 'married or civil partner', 32963, 0.0, 'Hancock, Townsend and Dennis', 9.63, 'CA7R 1RF', 'GB67PJWK79401973501118']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Amanda', 'Jones', 48, 'Female', 'Studio 11 Browne lodge', 'Lake Lynneville', 'Isuzu', 'Veloster', 2019, 'SUV', True, '3585600269061275', 367, '11/18', '12/30', 0.0, 0.0, '4', 'married or civil partner', 68221, 0.0, 'Edwards, Shaw and Lawrence', 16.04, 'SE2P 7YB', 'GB11TPEN76320397313327']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Darren', 'Nicholson', 91, 'Male', '62 Keith roads', 'Simpsonville', 'Pontiac', '3500 HD Regular Cab', 2001, 'Sedan', True, '4908670868247320772', 592, '08/22', '02/27', 0.0, 0.0, '1', 'married or civil partner', 58729, 27876.0, 'N/A', 0.0, 'G52 9QT', 'GB78UUSS80700664579880']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['James', 'Butler', 81, 'Male', 'Flat 15 Abdul views', 'Annettetown', 'Oldsmobile', 'Vibe', 1999, 'Van/Minivan', True, '6575334375220204', 756, '05/15', '08/30', 0.0, 0.0, '3', 'widowed', 28145, 13349.0, 'N/A', 0.0, 'IM3 6TF', 'GB24RSBX61020718475543']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Gareth', 'Sykes', 77, 'Male', '61 Joan summit', 'Saundersville', 'Chrysler', 'Traverse', 1995, 'SUV', True, '3577011930320142', 124, '03/22', '07/24', 0.0, 0.0, '2', 'single', 47859, 23810.0, 'N/A', 0.0, 'W50 7FQ', 'GB09MERE63429778449591']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Pauline', 'Fox', 35, 'Female', '5 Allen circles', 'Pearsonborough', 'Chevrolet', 'Crown Victoria', 1997, 'Pickup', True, '6011799347320658', 817, '01/15', '09/23', 0.0, 0.0, '2', 'married or civil partner', 60952, 0.0, 'Wood, Perry and Morrison', 14.89, 'M8G 5DN', 'GB92TAGU08816833713303']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Naomi', 'Williams', 82, 'Female', 'Flat 3 Joshua meadows', 'Lake Clifford', 'Scion', '500', 2007, 'Sedan', True, '2704014923695494', 170, '04/23', '06/23', 0.0, 0.0, '3', 'married or civil partner', 27041, 20443.0, 'N/A', 0.0, 'LN52 7RJ', 'GB42DMTP90922971134203']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Benjamin', 'Griffin', 91, 'Male', 'Studio 97 Carroll isle', 'Rickybury', 'Ford', 'ProMaster Cargo Van', 2003, 'SUV', True, '5147470598453908', 4434, '02/23', '01/30', 0.0, 0.0, '2', 'married or civil partner', 43238, 21203.0, 'N/A', 0.0, 'N27 1GW', 'GB33UOCC14502459474083']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Kevin', 'Harrison', 75, 'Male', '634 Yvonne ramp', 'North Roy', 'Chevrolet', 'LX', 2017, 'Van/Minivan', True, '3565150457713489', 604, '03/19', '01/20', 0.0, 0.0, '3', 'married or civil partner', 44644, 28776.0, 'N/A', 0.0, 'BR0Y 3ZN', 'GB54LBLQ78463409666531']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Lydia', 'Thompson', 72, 'Female', '7 Rose dale', 'South Chelsea', 'Audi', 'Vandura 3500', 1997, 'SUV', True, '6593027374888462', 539, '04/23', '10/27', 0.0, 0.0, '2', 'married or civil partner', 74511, 0.0, 'Allen Group', 16.99, 'RM7 9XX', 'GB67WCDX58285436560691']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Paige', 'Lees', 72, 'Female', '289 Judith crossroad', 'Williamsview', 'Dodge', 'Eldorado', 2005, 'Sedan', True, '4084798260681878860', 418, '03/22', '02/23', 0.0, 0.0, '1', 'divorced', 26210, 0.0, 'Roberts-Whitehouse', 8.04, 'E8 2YF', 'GB14OFRN24071536689247']
#
# ...
# ['Lindsey', 'Bibi', 79, 'Female', '8 Graham loaf', 'Port Tracy', 'Nissan', 'Z8', 1998, 'Pickup', True, '4247820781452793157', 872, '04/18', '01/28', 0.0, 0.0, '1', 'single', 92594, 30631.0, 'N/A', 0.0, 'L92 4FY', 'GB67GLKX36090375343021']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Mohamed', "O'Connor", 57, 'Male', '5 Davis unions', 'Browntown', 'BMW', 'QX', 2006, 'Van/Minivan', True, '4227395280130280', 140, '06/22', '08/31', 0.0, 0.0, '2', 'married or civil partner', 77564, 0.0, 'Harris-Sutton', 17.44, 'SL9 1JA', 'GB92THYC24572704097265']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Lindsey', 'Ryan', 19, 'Female', 'Studio 50 Byrne burg', 'Johnsonport', 'Lexus', 'Ram 1500 Quad Cab', 2013, 'SUV', True, '6508080160132425', 645, '01/22', '06/22', 0.0, 0.0, '3', 'married or civil partner', 76673, 0.0, 'Grant Group', 17.31, 'M4 8RH', 'GB72KOEN60144024307811']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Kathryn', 'Whittaker', 57, 'Female', '77 Kenneth viaduct', 'Port Iain', 'Audi', 'Savana 2500 Passenger', 2005, 'Van/Minivan', True, '2678094324779362', 876, '05/15', '11/25', 0.0, 0.0, '', 'married or civil partner', 28670, 0.0, 'Clark, Smith and Taylor', 8.64, 'WC7Y 7AL', 'GB56SBXV79356158489294']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Terry', 'Clark', 39, 'Male', '0 Tracy lodge', 'Kellymouth', 'Freightliner', 'CL-Class', 2007, 'Convertible', True, '3586342313551170', 381, '02/20', '03/20', 0.0, 0.0, '1', 'married or civil partner', 69532, 0.0, 'Ingram, Gardner and Doyle', 16.24, 'N88 0BQ', 'GB02DCNT03066082896195']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Christian', 'Martin', 72, 'Male', 'Flat 59R Jason canyon', 'Karenfurt', 'Volvo', '3000GT', 1997, 'Pickup', True, '38948196445791', 66, '11/21', '03/35', 0.0, 0.0, '3', 'single', 70273, 22896.0, 'N/A', 0.0, 'G1 3BY', 'GB80CPBB41602938547880']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Ian', 'Martin', 20, 'Male', 'Flat 88x Carly roads', 'Jordanville', 'Chevrolet', 'Mulsanne', 2016, 'Coupe', True, '3536460601586962', 860, '03/16', '06/17', 0.0, 0.0, '2', 'married or civil partner', 33940, 0.0, 'Marshall, Walters and Smith', 9.84, 'PH6A 9NU', 'GB46YAGE60504663977181']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Ronald', 'Bennett', 27, 'Male', 'Flat 4 Oliver loop', 'North Jackchester', 'Ferrari', 'XJ', 2005, 'Sedan', True, '4603830069176344271', 119, '05/22', '04/26', 0.0, 0.0, '2', 'married or civil partner', 50236, 0.0, 'Lee PLC', 13.06, 'TD42 2EE', 'GB87FPEU91367975795176']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Kyle', 'Sims', 72, 'Male', 'Studio 40 Joe station', 'Matthewmouth', 'MAZDA', 'Tacoma Xtracab', 2007, 'SUV', True, '4335088296047', 484, '04/21', '04/25', 0.0, 0.0, '3', 'single', 97544, 32718.0, 'N/A', 0.0, 'B59 8GG', 'GB61SOTK38206188128073']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Mohammad', 'Wilson', 19, 'Male', '5 Connor square', 'Hilaryfort', 'Mercedes-Benz', 'GLA-Class', 1999, 'Pickup', True, '378444077395980', 854, '08/22', '08/24', 0.0, 0.0, '2', 'married or civil partner', 30168, 0.0, 'Archer Ltd', 8.99, 'NN9A 6GS', 'GB42BYUF70182831779930']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Jasmine', 'Bond', 25, 'Female', '5 Clifford mission', 'Jonesberg', 'BMW', 'Rally Wagon 3500', 2018, 'Sedan', True, '4256658200450276', 295, '10/18', '08/27', 0.0, 0.0, '2', 'single', 82525, 0.0, 'Carter PLC', 18.14, 'S0 9EU', 'GB38VYRP38251763717402']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Nicole', 'Whitehead', 22, 'Female', 'Studio 1 Perkins rapids', 'Lake Sharon', 'Chevrolet', 'E250 Cargo', 2020, 'Sedan, Hatchback', True, '371511929771522', 127, '03/22', '09/29', 0.0, 0.0, '4', 'single', 66797, 0.0, 'Sharpe, Richardson and Green', 15.82, 'RM2 0PN', 'GB49QOBF69628386265712']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Louis', 'Leonard', 37, 'Male', '4 Henry points', 'West Rhysfurt', 'Hyundai', 'Silverado (Classic) 1500 HD Crew Cab', 2006, 'Van/Minivan', True, '4300668320666867085', 6083, '03/17', '12/25', 0.0, 0.0, '2', 'married or civil partner', 37807, 0.0, 'Gordon, Carey and Edwards', 10.67, 'NW0V 5QZ', 'GB83GJEO03803888176852']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Shirley', 'Crawford', 60, 'Female', 'Studio 03r Sylvia mountains', 'West Jenna', 'Kia', 'Phantom', 2001, 'Sedan', True, '6011413175333623', 96, '03/19', '08/29', 0.0, 0.0, '1', 'married or civil partner', 86177, 0.0, 'Andrews and Sons', 18.65, 'TS5P 6YH', 'GB20GZMC34230381818938']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Patricia', 'Morris', 89, 'Female', 'Flat 96E Judith roads', 'Bernardland', 'Ford', 'RDX', 1998, 'SUV', True, '4070256405100723', 257, '05/23', '05/30', 0.0, 0.0, '3', 'single', 65450, 28545.0, 'N/A', 0.0, 'E8E 8QS', 'GB97OWDC82982897664246']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Laura', 'Collins', 61, 'Female', 'Flat 05t Williams greens', 'Margaretstad', 'Pontiac', 'Explorer Sport Trac', 2015, 'SUV', True, '3576117890885478', 5082, '04/19', '02/31', 0.0, 0.0, '3', 'married or civil partner', 28770, 0.0, 'Taylor Group', 8.67, 'JE1M 8GD', 'GB69ZXNF07890507935209']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Diana', 'Barker', 35, 'Female', 'Studio 2 Foster unions', 'Port Samfurt', 'Acura', 'Yukon', 2005, 'Sedan, Wagon', True, '4328285282373', 516, '09/22', '07/28', 0.0, 0.0, '3', 'widowed', 64378, 0.0, 'Jenkins-Schofield', 15.44, 'DY1 1XG', 'GB79REQQ85633201725953']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Rosemary', 'Smith', 84, 'Female', 'Flat 34 Jones gardens', 'Rickyfort', 'Chevrolet', 'Impala', 2012, 'Pickup', True, '3546704545275044', 677, '01/23', '04/29', 0.0, 0.0, '2', 'married or civil partner', 38640, 22378.0, 'N/A', 0.0, 'WA7 3XR', 'GB29JJIZ46250863443100']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Joe', 'Whitehead', 79, 'Male', '842 Noble dale', 'Simpsonberg', 'Hyundai', 'Pilot', 2008, 'SUV', True, '6011133256086946', 643, '08/15', '06/27', 0.0, 0.0, '4', 'married or civil partner', 71987, 29016.0, 'N/A', 0.0, 'W8U 0FF', 'GB68PERK96488422264216']
#
# INSERT INTO `customerentity` (`firstname`, `lastname`, `age`, `sex`, `address_main`, `address_city`, `vehicle_make`, `vehicle_model`, `vehicle_year`, `vehicle_type`, `retired`, `credit_card_number`, `credit_card_security_code`, `credit_card_start_date`, `credit_card_end_date`, `dept_amount`, `dept_time_period_years`, `dependants`, `marital_status`, `salary`, `pension`, `company`, `commute_distance`, `address_postcode`, `iban`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ['Ruth', 'Green', 73, 'Female', 'Studio 21O Ronald wells', 'Lake Anne', 'Ford', 'Transit 350 Wagon', 1998, 'SUV', True, '36359981372798', 48, '11/19', '10/24', 0.0, 0.0, '2', 'married or civil partner', 22271, 0.0, 'Bruce Group', 7.02, 'L9H 5SF', 'GB77XAWG23927418836112']
#
# COMMIT
# Entries Added Successfully
